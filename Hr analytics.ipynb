# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\Arigala.Adarsh\Downloads\Intellepaat\employees (1).csv")

# %%
df.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
a=['dept','numberOfProjects','timeSpent.company','workAccident','promotionInLast5years','salary']

# %%
for i,j in enumerate(a):
    print(i,j)
# Out:
# 0 dept
# 1 numberOfProjects
# 2 timeSpent.company
# 3 workAccident
# 4 promotionInLast5years
# 5 salary

# %%
fid=plt.subplots(3,2,figsize=(30,25))
for i,j in enumerate(a):
    plt.subplot(3,2,i+1)
    sns.countplot(x=j,data=df,hue='left')
plt.show()

# %%
a="Study C"
print(len(a))
# Out:
# 7

# %%
a=5
print("square {0} ".format(a**2))
# Out:
# square 25

# %%
name = input("Enter your name: ") # user input
current_age = int(input("Enter your age: ")) # user input
#calculating the 100th year, considering 2020 as the current year
hundredth_year = 2020 + (100 - current_age)
print(f'{name} will become 100 years old in the year {hundredth_year}.')
# Out:
# Enter your name: v
# Enter your age: 13
# v will become 100 years old in the year 2107.

# %%
a=int(input( ))
b=a**2
c=a**3

print("square of number is {0} and Cube of number is {1}".format(b,c))
# Out:
# 4
# square of number is 16 and Cube of number is 64
